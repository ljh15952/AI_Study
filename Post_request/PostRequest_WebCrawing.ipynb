# %%
# !pip install requests
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# You should consider upgrading via the 'c:\users\ljh15\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
import json

import requests # requests.get(URL).content
from bs4 import BeautifulSoup

# %%
# 안되는 코드 방법

url = 'https://golmok.seoul.go.kr/stateArea.do'

response = requests.get(url).content
web_page = BeautifulSoup(response,'html.parser')
web_page

# -> Ctrl + F 후 브라우저 상에서 보이는 특정 수치 값으로 검색해 값이 들어있는지 확인
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <!--  meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no"-->
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="서울시,골목,골목상권,우리마을가게,상권,상권분석,상권분석서비스" name="keywords">
# <meta content="우리마을가게 상권분석 서비스 - 서울시가 골목상권 분석을 도와 드립니다! 상권 관련 빅데이터를 토대로 100개 생활밀착 업종별 다양한 정보를 골목상권단위로 제공합니다. " name="description"/>
# <title>
#
# 			지역·상권별 현황 - 지역별 현황
#
# 		: 우리마을가게 상권분석 서비스
# 	</title>
# <!-- [M 2021-12-15] 파비콘 추가 -->
# <link href="/new/images/favicon.ico" rel="shortcut icon"/>
# <!-- 카카오 API , 맵 -->
# <script src="/js/lib/kakao.min.js"></script>
# <!-- <script src="https://dapi.kakao.com/v2/maps/sdk.js?appkey=4922f2d70dcdad5584724401e42777ad&libraries=services"></script> -->
# ...

# %%
data = {
    'stdrYyCd': '2022',
    'stdrSlctQu': 'sameQu',
    'stdrQuCd': '2',
    'stdrMnCd': '202206',
    'selectTerm': 'quarter',
    'svcIndutyCdL': 'CS000000',
    'svcIndutyCdM': 'all',
    'stdrSigngu': '11',
    'selectInduty': '1',
    'infoCategory': 'rent'
}

# %%
response = requests.post('https://golmok.seoul.go.kr/region/selectStoreCount.json',data=data).content

# %%
result = json.loads(response)

# %%
result
# Out:
# [{'NM': '서울시 전체',
#   'CD': '11',
#   'GUBUN': 'si',
#   'FIRST_TOT': 575303,
#   'FIRST_NOR': 528691,
#   'FIRST_FRC': 46612,
#   'SECOND_TOT': 572073,
#   'SECOND_NOR': 526275,
#   'SECOND_FRC': 45798,
#   'THIRD_TOT': 577194,
#   'THIRD_NOR': 531897,
#   'THIRD_FRC': 45297},
#  {'NM': '종로구',
#   'CD': '11110',
#   'GUBUN': 'gu',
#   'FIRST_TOT': 25318,
#   'FIRST_NOR': 23710,
#   'FIRST_FRC': 1608,
#   'SECOND_TOT': 24835,
#   'SECOND_NOR': 23333,
#   'SECOND_FRC': 1502,
#   'THIRD_TOT': 24807,
#   'THIRD_NOR': 23344,
#   'THIRD_FRC': 1463},
#  {'NM': '청운효자동',
#   'CD': '11110515',
#   'GUBUN': 'dong',
#   'FIRST_TOT': 757,
#   'FIRST_NOR': 735,
#   'FIRST_FRC': 22,
#   'SECOND_TOT': 758,
#   'SECOND_NOR': 737,
#   'SECOND_FRC': 21,
#   'THIRD_TOT': 799,
#   'THIRD_NOR': 778,
#   'THIRD_FRC': 21},
#  {'NM': '사직동',
#   'CD': '11110530',
#   'GUBUN': 'dong',
#   'FIRST_TOT': 2696,
#   'FIRST_NOR': 2494,
#   'FIRST_FRC': 202,
#   'SECOND_TOT': 2683,
#   'SECOND_NOR': 2498,
# ...

# %%
temp_data = []

for item in result:
    temp_data.append(item['FIRST_TOT'])
    
temp_data
# Out:
# [575303,
#  25318,
#  757,
#  2696,
#  706,
#  397,
#  570,
#  196,
#  423,
#  583,
#  11030,
#  2094,
#  836,
#  1498,
#  1779,
#  347,
#  163,
#  267,
#  976,
#  40015,
#  2752,
#  5720,
#  5233,
#  1229,
#  480,
#  6534,
#  2969,
#  9589,
#  930,
#  645,
#  495,
#  824,
#  651,
#  1256,
#  708,
#  18924,
#  699,
#  541,
#  1449,
#  1243,
#  1650,
#  1025,
#  324,
#  547,
#  5055,
#  820,
#  218,
#  1692,
#  697,
#  2026,
#  301,
#  637,
#  17062,
#  556,
#  1603,
#  2221,
#  835,
#  1076,
#  468,
#  237,
#  395,
#  808,
#  489,
#  715,
#  840,
#  1401,
#  1343,
#  2392,
#  381,
#  1302,
#  18984,
#  2201,
#  1243,
#  1032,
#  1263,
#  870,
#  979,
#  595,
#  1040,
#  1392,
#  979,
#  1150,
#  1327,
#  1494,
#  937,
#  2482,
#  21157,
#  2832,
#  3059,
#  1697,
#  631,
#  1334,
#  1476,
#  2858,
#  2176,
#  1314,
#  986,
#  818,
#  515,
#  1009,
#  452,
#  16180,
#  1076,
#  567,
#  407,
#  1593,
#  956,
#  1313,
#  767,
#  1470,
#  667,
#  1285,
#  1045,
#  934,
#  1829,
#  529,
# ...
