# %%
# 다음 사전(https://dic.daum.net/index.do)에 happiness 단어를 검색하였을 때 
# 출력되는 화면에서 단어와 단어의 의미를 출력한다.

# %%
# !pip install beautifulsoup4==4.9.3
# Out:
# ...
# WARNING: You are using pip version 20.2.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3.7 -m pip install --upgrade pip' command.

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
# https://dic.daum.net/search.do?q=happiness <- (Web) Query
# 다음 서버

# %%
# 검색하고 싶은 단어 입력하기
word = 'happiness'

# 불러오려는 url 입력하기
# 디폴트 url에 string 타입의 word 변수를 합쳐서 url 변수 생성
url = 'https://dic.daum.net/search.do?q=' + word

#urlopen 함수를 통해 web 변수를 생성
web = urlopen(url) #urlopen(url),read().decode('utf-8')

# BeautifulSoup으로 web 페이지상의 HTML 구조를 파싱
web_page = BeautifulSoup(web, 'html.parser')

print(web_page)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>happiness – 다음 어학사전</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="http://t1.daumcdn.net/thumb/P270x270/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flanguage%2Fcommon_icon%2F557565CB040E530001" property="og:image">
# <meta content="website" property="og:type"/>
# <meta content="Daum 사전" property="og:site_name"/>
# <meta content="" property="og:description"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Daum 사전" name="twitter:title"/>
# <meta content="" name="twitter:site"/>
# <meta content="" name="twitter:creator"/>
# <meta content="" name="twitter:description"/>
# <meta content="http://t1.daumcdn.net/thumb/P270x270/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flanguage%2Fcommon_icon%2F557565CB040E530001" name="twitter:image"/>
# ...

# %%
# Parser <- 구문, 문법을 해석하는 느낌
# 여러 종류가 있음

# %%
web_page.find('p') #태그중 가장 첫번째를 꺼냄
# Out:
# <p class="txt_norecent" id="recentWordNoResult" style="display:none">최근검색어 내역이 없습니다.</p>

# %%
web_page.find_all('p') # 찾아낸 모든 태그를 리스트(와 비슷한 자료형)로 반환
# Out:
# [<p class="txt_norecent" id="recentWordNoResult" style="display:none">최근검색어 내역이 없습니다.</p>,
#  <p class="word_desc">확인을 누르시면 새로 만든 단어장으로 자동 저장됩니다.</p>,
#  <p class="word_make">저장할 단어장이 없습니다.<br/>단어장을 만들어주세요.</p>,
#  <p>위 내용에 대한 저작권 및 법적 책임은 자료 제공사 또는 글쓴이에 있으며 Kakao의 입장과 다를 수 있습니다.</p>,
#  <p class="desc_report m_none">사전에 없는 단어나 내용 오류, 오타를 신고해 주세요.</p>,
#  <p class="desc_report">등록해 주신 내용은 운영자의 검토를 거쳐, 서비스에 반영됩니다.</p>]

# %%
web_page.find('p').get_text() # 태그 안의 텍스트를 반환
# Out:
# '최근검색어 내역이 없습니다.'

# %%
web_page.find('p').attrs # 속성들을 dict 형태로 반환
# Out:
# {'id': 'recentWordNoResult',
#  'class': ['txt_norecent'],
#  'style': 'display:none'}

# %%
# 찾는 단어 (대상이 하나일 때)

box1 = web_page.find("span",{'class':'txt_emph1'}) # 찾기
print(box1)
print(box1.get_text())
# Out:
# <span class="txt_emph1">happiness</span>
# happiness

# %%
box2 = web_page.find_all("span",{"class":"txt_search"})
box2
# Out:
# [<span class="txt_search"><daum:word id="kew000082679">행복</daum:word></span>,
#  <span class="txt_search"><daum:word id="kew000011479">기쁨</daum:word></span>,
#  <span class="txt_search"><daum:word id="kew000023060">만족</daum:word></span>,
#  <span class="txt_search"><daum:word id="kew000082703">행운</daum:word></span>,
#  <span class="txt_search"><daum:word id="kew000082679">행복</daum:word><daum:word id="kew000057049">을</daum:word> <daum:word id="kew000000776">가져다</daum:word> <daum:word id="kew000066209">주다</daum:word></span>,
#  <span class="txt_search"><daum:word id="kew000082679">행복</daum:word><daum:word id="kew000057049">을</daum:word> <daum:word id="kew000095119">추구하다</daum:word></span>,
#  <span class="txt_search"><daum:word id="kkw000152622">순간적</daum:word><daum:word id="kew000058444">인</daum:word> <daum:word id="kew000082679">행복</daum:word></span>,
# ...

# %%
# find_all()로 여러개의 단어 get_text()

for defination in box2:
    print(defination.get_text())
# Out:
# 행복
# 기쁨
# 만족
# 행운
# 행복을 가져다 주다
# 행복을 추구하다
# 순간적인 행복
# state of well-being characterized by emotions ranging from contentment to intense joy
# the right to try to find happiness
# 해피니스. 행복

# %%
words = ['state','character','emotion','content','intense']

url = url = 'https://dic.daum.net/search.do?q=' + 'state'

http_response = urlopen(url)
html_source = BeautifulSoup(http_response,'html.parser')

print(html_source.find_all('span'))
